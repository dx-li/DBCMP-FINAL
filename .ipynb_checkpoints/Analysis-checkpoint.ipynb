# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("DataSet.csv")
df.head()
# Out:
#   Country Name  Date  CO2 emissions (metric tons per capita)  \
# 0    Australia  2002                               17.957499
# 1    Australia  2003                               17.692029
# 2    Australia  2004                               18.147898
# 3    Australia  2005                               18.117854
# 4    Australia  2006                               18.120679
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           5.678274
# 1                                           5.639166
# 2                                           5.813457
# 3                                           5.739874
# 4                                           5.725736
#
#    Domestic general government health expenditure per capita (current US$)  \
# 0                                        1273.632403
# 1                                        1604.672295
# 2                                        1983.680272
# ...

# %%
df.columns =["COUNTRY", 'DATE', 'CO2E', 'DGGHE', 'DGGHEPC', "MRU5"]

# %%
from plotnine import *

# %%
ggplot(df, aes("CO2E", "MRU5", color = "COUNTRY")) + geom_line() + facet_wrap("~COUNTRY")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/spr22/lib/python3.10/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (681370895)>

# %%
ggplot(df, aes("DGGHEPC", "MRU5", color = "COUNTRY")) + geom_line() + facet_wrap("~COUNTRY")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/spr22/lib/python3.10/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (681337085)>

# %%
df_indexed = df.set_index(["COUNTRY", "DATE"])

# %%
df_indexed.head()
# Out:
#                      CO2E     DGGHE      DGGHEPC  MRU5
# COUNTRY   DATE
# Australia 2002  17.957499  5.678274  1273.632403   6.0
#           2003  17.692029  5.639166  1604.672295   5.9
#           2004  18.147898  5.813457  1983.680272   5.8
#           2005  18.117854  5.739874  2164.526424   5.7
#           2006  18.120679  5.725736  2282.434199   5.6
